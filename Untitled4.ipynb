# %% [markdown]
# <a href="https://colab.research.google.com/github/NorahAlShaikhMubarak/LogisticClassifier-DecisionTree/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Necessary Libararies
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# !matplotlib

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier #Import Dicision Tree Classifier  
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

from sklearn.tree import export_graphviz 
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus

iris = datasets.load_iris()

#Convert Numpy to DataFrame from Analysis
df=pd.DataFrame(iris.data)
df.columns =[iris.feature_names]
df['Labels']=iris.target
print(df.shape)
print(iris.target_names)
df.head()
# Out:
# /bin/bash: matplotlib: command not found
# (150, 5)
# ['setosa' 'versicolor' 'virginica']
#   sepal length (cm) sepal width (cm) petal length (cm) petal width (cm) Labels
# 0               5.1              3.5               1.4              0.2      0
# 1               4.9              3.0               1.4              0.2      0
# 2               4.7              3.2               1.3              0.2      0
# 3               4.6              3.1               1.5              0.2      0
# 4               5.0              3.6               1.4              0.2      0

# %%
#feature and Label
X=iris.data
y=iris.target

#Split dataset into training set and test sat 
X_train, X_test, y_train , y_test = train_test_split(X,y,test_size=0.3,random_state=1) #70% training and 30% test

#Create Decision Tree classifer object
clf=DecisionTreeClassifier()

#Train Decision Tree classifer object
clf=clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred= clf.predict(X_test)

#Model Accuracy, how often is the classifier correct?
print ("Accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.9555555555555556

# %%
from sklearn.tree import export_graphviz
export_graphviz(clf,out_file='tree_limited.dotr',feature_names=iris.feature_names,class_names=iris.target_names,rounded=True,proportion=False,precision=2,filled=True)

import os
os.environ["PATH"]+=os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

#!dot-tpng tree_limited.dot -o tree_limited.png -gdpi=600
dot_data=StringIO()
export_graphviz(clf,out_file=dot_data,filled=True , rounded=True , special_characters=True,feature_names=iris.feature_names,class_names=iris.target_names)
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('iris_tree.png')
Image(graph.create_png())
